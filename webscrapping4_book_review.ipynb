# %% [markdown]
# **WEBSCRAPPING PROBLEM:4**

# %% [markdown]
# # BOOK REVIEW

# %% [markdown]
# ***PROBLEM STATEMENT:*** Write a python program to scrap,
# 1. Book name
# 2. Author name
# 3. Genre
# 4. Book review of any 5 books from ‘www.bookpage.com’.

# %% [markdown]
# ### IMPORTING LIBRARIES

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %% [markdown]
# ### EXTRACTING DATA

# %%
# Checking if we have the permission to scrap the webpage.

page= requests.get("https://bookpage.com/reviews")
page
# Out:
# <Response [200]>

# %% [markdown]
# we are permitted to extract data from IMBD website.

# %%
# Now we will parse this source code by using BeatifulSoup and parser used here is html.parser as source code is in HTML.
soup=BeautifulSoup(page.text, 'html.parser')

# %%
# Page title
soup.title.text
# Out:
# 'Book Reviews | BookPage'

# %%
# Required data lists
book_name =[]
author_name =[]
genre = []
book_review =[]

# %%
# Now lets extract all html tags with movie Names.
book_data= soup.findAll('div', class_ ='bp-block article-info')
book_data
# Out:
# [<div class="bp-block article-info">
#  <div class="article-list-left">
#  <a href="/reviews/26206-daniel-james-brown-facing-mountain-history"><img alt="Medium" src="https://t1.bookpage.com/books/images/4f0d984552cb3275e25c98873dfeca73/medium.jpg"/></a>
#  </div>
#  <div class="flex-article-content">
#  <h4 class="italic">
#  <a href="/reviews/26206-daniel-james-brown-facing-mountain-history"> <span style="font-style:normal;">★ </span>Facing the Mountain</a>
#  </h4>
#  <p class="sans bold">
#  Daniel James Brown
#  </p>
#  <p class="genre-links hidden-phone">
#  <a href="/search?book_genre=nonfiction">Nonfiction</a>
#   /
#  <a href="/search?book_genre=history">History</a>
#   /
#  <a href="/search?book_genre=american_history">American History</a>
#  </p>
#  <p class="excerpt">
#  Most of the Japanese American patriots who formed the 442nd Infantry Regiment are gone, but their stories live on in this empathetic tribute to their courage.
#  </p>
#  <div class="read-full">
# ...

# %%
# Collecting column data
for i in book_data:
    name = i.h4.a.text
    book_name.append(name)
    
    author= i.p.text.replace("\n", " ")
    author_name.append(author)
    
    book_genre= i.find('p', class_ = 'genre-links hidden-phone').text.replace("\n"," ")
    genre.append(book_genre)
    
    review = i.find('p', class_='excerpt').text.replace("\n", " ")
    book_review.append(review)

# %%
# Tabulating data
book_details =  pd.DataFrame({})
book_details['book_name']= book_name
book_details['author_name']= author_name
book_details['genre'] = genre
book_details['book_review'] = book_review

# %%
book_details.head()
# Out:
#                          book_name            author_name  \
# 0            ★ Facing the Mountain    Daniel James Brown
# 1                       Lucky Girl          Jamie Pacton
# 2                  ★ On Juneteenth   Annette Gordon-Reed
# 3                         Pawcasso              Remy Lai
# 4  The Most Beautiful Girl in Cuba        Chanel Cleeton
#
#                                            genre  \
# 0   Nonfiction  /  History  /  American History
# 1                             YA Fiction  /  YA
# 2   Nonfiction  /  History  /  American History
# 3                   Children's  /  Middle Grade
# 4                Fiction  /  Historical Fiction
#
#                                          book_review
# 0   Most of the Japanese American patriots who fo...
# 1   Seventeen-year-old Jane Belleweather has just...
# 2   Gordon-Reed’s essays seamlessly merge history...
# 3   Pawcasso is a joyful graphic novel from accla...
# 4   Chanel Cleeton delivers a sweeping story of l...
